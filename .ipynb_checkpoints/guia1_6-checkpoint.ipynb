# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df1 = pd.read_csv("casos.csv")
df2 = pd.read_csv("gordon.csv")

# %%
df1.estado_caso.value_counts()
# Out:
# 3    14
# 2    10
# 1     8
# Name: estado_caso, dtype: int64

# %%
df2.head()
# Out:
#    id_caso  respuesta
# 0      100          1
# 1      101          0
# 2      102          0
# 3      103          1
# 4      104          1

# %%
# Tasa de resolución de casos de la fuerza policial por categoría de caso (considerando
# aquellos casos en los que no participó Batman).

    
def contar_n(serie, n):

    serie = serie.apply(lambda x: 1 if x==n else 0)#.apply(hacer_dos)
    return np.sum(serie)

def contar_distinto_a_n(serie, n):

    serie = serie.apply(lambda x: 1 if x!=n else 0)#.apply(hacer_dos)
    return np.sum(serie)

#Cuento los que tienen estado 2
df3 = df1.groupby('categoria')['estado_caso'].agg(lambda x: contar_n(x, 2)).reset_index()

#Cuento los que tienen estado distinto de 2
#df4 = df1.groupby('categoria')['estado_caso'].agg(lambda x: contar_distinto_a_n(x, 2)).reset_index()
#NO ERA NECESARIO, ME INTERESABAN LOS TOTALES

#Cuento todos los casos
df4 = df1.groupby('categoria').agg({'estado_caso' : 'count'}).reset_index()

# %%
df3.rename(columns = {'estado_caso' : 'casos_resueltos'}, inplace = True)
df3.head(10)
# Out:
#   categoria  casos_resueltos
# 0      cat1                1
# 1      cat2                2
# 2      cat3                1
# 3      cat4                4
# 4      cat5                1
# 5      cat6                1
# 6      cat7                0
# 7      cat8                0

# %%
df4.rename(columns = {'estado_caso' : 'casos_totales'}, inplace = True)
df4.head(10)
# Out:
#   categoria  casos_totales
# 0      cat1              2
# 1      cat2              3
# 2      cat3              5
# 3      cat4              7
# 4      cat5              6
# 5      cat6              5
# 6      cat7              3
# 7      cat8              1

# %%
#Hago un join de los dos dataframes

tasa_casos = pd.merge(df4, df3, on = 'categoria', how = 'inner')
tasa_casos.head(10)
# Out:
#   categoria  casos_totales  casos_resueltos
# 0      cat1              2                1
# 1      cat2              3                2
# 2      cat3              5                1
# 3      cat4              7                4
# 4      cat5              6                1
# 5      cat6              5                1
# 6      cat7              3                0
# 7      cat8              1                0

# %%
tasa_casos['tasa de resolucion'] = tasa_casos['casos_resueltos'] / tasa_casos['casos_totales'] * 100
tasa_casos.head()
# Out:
#   categoria  casos_totales  casos_resueltos  tasa de resolucion
# 0      cat1              2                1           50.000000
# 1      cat2              3                2           66.666667
# 2      cat3              5                1           20.000000
# 3      cat4              7                4           57.142857
# 4      cat5              6                1           16.666667

# %%
# Tasa de resolución de casos con la ayuda de Batman (considerando que aquellos casos
# en los que fue llamado con la batiseñal, participó en la resolución)
# Es el mismo procedimiento pero debo filtrar antes aquellos donde no ayudo batman

casos_batman = pd.merge(df1, df2, on = 'id_caso', how = 'inner')
casos_batman = casos_batman[casos_batman['respuesta'] == 1]
casos_batman.head()
# Out:
#       fecha  id_caso         descripcion  estado_caso categoria latitud  \
# 0  08/08/19      100   aca iria una desc            1      cat1     34°
# 3  05/08/19      103  aca iria otra desc            3      cat4     35°
# 4  07/08/19      104   aca iria una desc            2      cat1     33°
# 6  05/09/19      106   aca iria una desc            2      cat4     36°
# 8  07/09/19      108   aca iria una desc            2      cat3    -32°
#
#   longitud  respuesta
# 0      35°          1
# 3      36°          1
# 4      34°          1
# 6      37°          1
# 8     -33°          1

# %%
#Cuento todos los casos en los que participo que tienen estado 2
df5 = casos_batman.groupby('categoria')['estado_caso'].agg(lambda x: contar_n(x, 2)).reset_index()

#Cuento todos los casos en los que participo
df6 = casos_batman.groupby('categoria').agg({'estado_caso' : 'count'}).reset_index()

# %%
df5.rename(columns = {'estado_caso' : 'casos_resueltos'}, inplace = True)
df5.head(10)
# Out:
#   categoria  casos_resueltos
# 0      cat1                1
# 1      cat2                1
# 2      cat3                1
# 3      cat4                3
# 4      cat5                1
# 5      cat6                1
# 6      cat7                0

# %%
df6.rename(columns = {'estado_caso' : 'casos_totales'}, inplace = True)
df6.head(10)
# Out:
#   categoria  casos_totales
# 0      cat1              2
# 1      cat2              1
# 2      cat3              2
# 3      cat4              5
# 4      cat5              3
# 5      cat6              3
# 6      cat7              2

# %%
#Hago un join de los dos dataframes

casos_batman = pd.merge(df5, df6, on = 'categoria', how = 'inner')
casos_batman.head(10)
# Out:
#   categoria  casos_resueltos  casos_totales
# 0      cat1                1              2
# 1      cat2                1              1
# 2      cat3                1              2
# 3      cat4                3              5
# 4      cat5                1              3
# 5      cat6                1              3
# 6      cat7                0              2

# %%
#Hago un join de los dos dataframes

casos_batman['tasa de res con batman'] = casos_batman['casos_resueltos'] / casos_batman['casos_totales'] * 100
casos_batman.head(8)
# Out:
#   categoria  casos_resueltos  casos_totales  tasa de res con batman
# 0      cat1                1              2               50.000000
# 1      cat2                1              1              100.000000
# 2      cat3                1              2               50.000000
# 3      cat4                3              5               60.000000
# 4      cat5                1              3               33.333333
# 5      cat6                1              3               33.333333
# 6      cat7                0              2                0.000000

# %%
# Indicar el mes del año pasado en el que Batman tuvo mayor participación en la
# investigación de casos.

#Entonces otra vez mergeo para saber en cuales participo Batman
casos_total = pd.merge(df1, df2, on = 'id_caso', how = 'inner')

#Convierto a datetime
casos_total['fecha'] = pd.to_datetime(casos_total['fecha'])

#Preparo columnas de mes y de anio
casos_total['mes'] = casos_total['fecha'].dt.month
casos_total['anio'] = casos_total['fecha'].dt.year

#Filtro por 2019
casos_total_2019 = casos_total.loc[casos_total['anio'] == 2019]

casos_total_2019.head()
# Out:
#        fecha  id_caso         descripcion  estado_caso categoria latitud  \
# 0 2019-08-08      100   aca iria una desc            1      cat1     34°
# 1 2019-07-08      101  aca iria otra desc            2      cat2     32°
# 2 2019-06-08      102   aca iria una desc            3      cat3    -30°
# 3 2019-05-08      103  aca iria otra desc            3      cat4     35°
# 4 2019-07-08      104   aca iria una desc            2      cat1     33°
#
#   longitud  respuesta  mes  anio
# 0      35°          1    8  2019
# 1      33°          0    7  2019
# 2     -31°          0    6  2019
# 3      36°          1    5  2019
# 4      34°          1    7  2019

# %%
casos_con_batman = casos_total_2019.loc[casos_total['respuesta'] == 1]
casos_con_batman.head()
# Out:
#        fecha  id_caso         descripcion  estado_caso categoria latitud  \
# 0 2019-08-08      100   aca iria una desc            1      cat1     34°
# 3 2019-05-08      103  aca iria otra desc            3      cat4     35°
# 4 2019-07-08      104   aca iria una desc            2      cat1     33°
# 6 2019-05-09      106   aca iria una desc            2      cat4     36°
# 8 2019-07-09      108   aca iria una desc            2      cat3    -32°
#
#   longitud  respuesta  mes  anio
# 0      35°          1    8  2019
# 3      36°          1    5  2019
# 4      34°          1    7  2019
# 6      37°          1    5  2019
# 8     -33°          1    7  2019

# %%
casos_mensuales_batman = casos_con_batman.groupby('mes').agg({'id_caso' : 'count'}).reset_index()
casos_mensuales_batman.rename(columns = {'id_caso' : 'casos_batman'}, inplace = True)
casos_mensuales_batman
# Out:
#    mes  casos_batman
# 0    5             7
# 1    6             3
# 2    7             5
# 3    8             3

# %%
casos_mensuales = casos_total_2019.groupby('mes').agg({'id_caso' : 'count'}).reset_index()
casos_mensuales.rename(columns = {'id_caso' : 'casos_en_total'}, inplace = True)
casos_mensuales
# Out:
#    mes  casos_en_total
# 0    5               8
# 1    6               9
# 2    7               9
# 3    8               6

# %%
comp_casos_mensuales = pd.merge(casos_mensuales, casos_mensuales_batman, on = 'mes', how = 'left')
comp_casos_mensuales
# Out:
#    mes  casos_en_total  casos_batman
# 0    5               8             7
# 1    6               9             3
# 2    7               9             5
# 3    8               6             3

# %%
comp_casos_mensuales['participacion_batman'] = comp_casos_mensuales['casos_batman'] / comp_casos_mensuales['casos_en_total'] * 100
comp_casos_mensuales
# Out:
#    mes  casos_en_total  casos_batman  participacion_batman
# 0    5               8             7             87.500000
# 1    6               9             3             33.333333
# 2    7               9             5             55.555556
# 3    8               6             3             50.000000

# %%
comp_casos_mensuales.sort_values('participacion_batman', ascending = False)
# Out:
#    mes  casos_en_total  casos_batman  participacion_batman
# 0    5               8             7             87.500000
# 2    7               9             5             55.555556
# 3    8               6             3             50.000000
# 1    6               9             3             33.333333

# %%
comp_casos_mensuales.iloc[0,:]
# Out:
# mes                      5.0
# casos_en_total           8.0
# casos_batman             7.0
# participacion_batman    87.5
# Name: 0, dtype: float64
